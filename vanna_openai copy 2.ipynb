# %%
# !pip install vanna[chromadb,openai]

from vanna.openai import OpenAI_Chat
from vanna.chromadb import ChromaDB_VectorStore
import os
from dotenv import load_dotenv
load_dotenv()

class MyVanna(ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI_Chat.__init__(self, config=config)


vn = MyVanna(config={'api_key': os.getenv('OPENAI_API_KEY'), 'model': 'gpt-4o-mini'})

odbc_conn_str = f"""DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={os.getenv('DB_SERVER')};DATABASE={os.getenv('DB_DATABASE')};UID={os.getenv('DB_USER')};PWD={os.getenv('DB_PASSWORD')};TrustServerCertificate={os.getenv('DB_TRUST_SERVER_CERTIFICATE')}"""

vn.connect_to_mssql(odbc_conn_str=odbc_conn_str)
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: vanna[chromadb,openai] in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (0.7.6)
# Requirement already satisfied: requests in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (2.32.3)
# Requirement already satisfied: tabulate in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (6.0.1)
# Requirement already satisfied: pandas in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (2.2.3)
# Requirement already satisfied: sqlparse in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (0.2.1)
# Requirement already satisfied: flask in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (3.1.0)
# Requirement already satisfied: flask-sock in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (2.0.40)
# Requirement already satisfied: chromadb in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (1.0.15)
# Requirement already satisfied: openai in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,openai]) (1.70.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (2.11.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai]) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (2.2.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (4.13.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (3.11.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,openai]) (4.23.0)
# Requirement already satisfied: mistune in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,openai]) (3.1.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,openai]) (1.17.0)
# Requirement already satisfied: packaging in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,openai]) (24.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,openai]) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,openai]) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,openai]) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,openai]) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,openai]) (1.9.0)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask-sock->vanna[chromadb,openai]) (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from openai->vanna[chromadb,openai]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from openai->vanna[chromadb,openai]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from openai->vanna[chromadb,openai]) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from openai->vanna[chromadb,openai]) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,openai]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,openai]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,openai]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from plotly->vanna[chromadb,openai]) (1.33.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,openai]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,openai]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,openai]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,openai]) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from sqlalchemy->vanna[chromadb,openai]) (3.1.1)
# Requirement already satisfied: pyproject_hooks in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from build>=1.0.3->chromadb->vanna[chromadb,openai]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from build>=1.0.3->chromadb->vanna[chromadb,openai]) (0.4.6)
# Requirement already satisfied: httpcore==1.* in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx>=0.27.0->chromadb->vanna[chromadb,openai]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->vanna[chromadb,openai]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from Jinja2>=3.1.2->flask->vanna[chromadb,openai]) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,openai]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,openai]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,openai]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,openai]) (0.24.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (6.31.1)
# Requirement already satisfied: sympy in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,openai]) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,openai]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->vanna[chromadb,openai]) (0.56b0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->vanna[chromadb,openai]) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,openai]) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,openai]) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,openai]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,openai]) (2.19.1)
# Requirement already satisfied: wsproto in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,openai]) (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb->vanna[chromadb,openai]) (0.33.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from typer>=0.9.0->chromadb->vanna[chromadb,openai]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai]) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai]) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (4.9.1)
# Requirement already satisfied: filelock in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,openai]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,openai]) (2025.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,openai]) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->vanna[chromadb,openai]) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai]) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai]) (0.6.1)

# %%
response = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")
print(response)  # Afficher la réponse brute
print(type(response))  # Pour voir si c'est bien un objet contenant du JSON
# Out:
# Requirement already satisfied: vanna[chromadb,ollama] in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (0.7.6)
# Requirement already satisfied: requests in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (2.32.3)
# Requirement already satisfied: tabulate in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (6.0.1)
# Requirement already satisfied: pandas in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (2.2.3)
# Requirement already satisfied: sqlparse in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.2.1)
# Requirement already satisfied: flask in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (3.1.0)
# Requirement already satisfied: flask-sock in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (2.0.40)
# Requirement already satisfied: chromadb in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (1.0.15)
# Requirement already satisfied: ollama in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.5.1)
# Requirement already satisfied: httpx in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.28.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (2.11.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (2.2.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.13.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (3.11.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.23.0)
# Requirement already satisfied: anyio in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (4.9.0)
# Requirement already satisfied: certifi in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (1.0.7)
# Requirement already satisfied: idna in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpcore==1.*->httpx->vanna[chromadb,ollama]) (0.14.0)
# Requirement already satisfied: mistune in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,ollama]) (3.1.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,ollama]) (1.17.0)
# Requirement already satisfied: packaging in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,ollama]) (24.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (1.9.0)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask-sock->vanna[chromadb,ollama]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,ollama]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,ollama]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,ollama]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from plotly->vanna[chromadb,ollama]) (1.33.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,ollama]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,ollama]) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from sqlalchemy->vanna[chromadb,ollama]) (3.1.1)
# Requirement already satisfied: pyproject_hooks in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from build>=1.0.3->chromadb->vanna[chromadb,ollama]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from build>=1.0.3->chromadb->vanna[chromadb,ollama]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from Jinja2>=3.1.2->flask->vanna[chromadb,ollama]) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (0.24.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (6.31.1)
# Requirement already satisfied: sympy in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,ollama]) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,ollama]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->vanna[chromadb,ollama]) (0.56b0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->vanna[chromadb,ollama]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->vanna[chromadb,ollama]) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,ollama]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,ollama]) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,ollama]) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,ollama]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,ollama]) (2.19.1)
# Requirement already satisfied: wsproto in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,ollama]) (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb->vanna[chromadb,ollama]) (0.33.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from typer>=0.9.0->chromadb->vanna[chromadb,ollama]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from anyio->httpx->vanna[chromadb,ollama]) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (4.9.1)
# Requirement already satisfied: filelock in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,ollama]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,ollama]) (2025.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,ollama]) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->vanna[chromadb,ollama]) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (0.6.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Récupérer les métadonnées du schéma
# df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME IN ('P_Zubeh', 'A_Kopf', 'P_Kaufm', 'A_Vorgang', 'P_Teil', 'P_Artikel', 'P_Werkstoffe', 'A_KopfFreie', 'A_Adresse')")



# Générer le plan d'entraînement
plan = vn.get_training_plan_generic(df_information_schema)
print(plan)

# Entraîner le modèle
vn.train(plan=plan)
# Out:
# Train on Information Schema: 3E_80_Commande.dbo A_Adresse
# Train on Information Schema: 3E_80_Commande.dbo A_Kopf
# Train on Information Schema: 3E_80_Commande.dbo A_KopfFreie
# Train on Information Schema: 3E_80_Commande.dbo A_Vorgang
# Train on Information Schema: 3E_80_Commande.dbo P_Artikel
# Train on Information Schema: 3E_80_Commande.dbo P_Kaufm
# Train on Information Schema: 3E_80_Commande.dbo P_Teil
# Train on Information Schema: 3E_80_Commande.dbo P_Werkstoffe
# Train on Information Schema: 3E_80_Commande.dbo P_Zubeh

# %%
vn.train(
    question="""Combien de fois un article a-t-il été utilisé, et quelles sont ses dimensions totales en mL pour l'année 2024 ?""",
    sql="""
    SELECT 
        Paramgen.ArtikelID AS [Article],
        COUNT(Cde.AuNummer) AS [Nbr d'utilisations],
        SUM(Paramgen.Dim1) / 1000 AS [Dim 1 (mL)]

    FROM dbo.P_Artikel AS Paramgen                
    LEFT JOIN dbo.A_Kopf AS Cde ON Cde.ID = Paramgen.ID_A_Kopf
    LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf

    WHERE 
        cf.Feld3 BETWEEN '2024-01-01' AND '2024-12-31'
        AND Paramgen.ArtikelID = '2104'
    GROUP BY Paramgen.ArtikelID;
    """
)

vn.train(
    question="liste moi les 10 dernieres commandes avec leur Extensions ?", 
    sql="""SELECT TOP 10 
            Cde.AuNummer as [Numéro de commande], Cde.AuAlpha as [Extension], Cde.AufStatus as [Statut], Convert(date, cf.Feld3) as [Date entrée de commande]
        FROM A_kopf as Cde
        LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
        ORDER BY cf.Feld3 DESC"""
)

vn.train(
    question="Liste des commandes où l'article 6101 est présent par extension, position et quantité entre en décembre 2024 ?",
    sql="""
        SELECT
            Paramgen.ArtikelID AS [Article],
            CONVERT(VARCHAR, Cde.AuNummer) AS [N° de Cde],
            Cde.AuAlpha AS Extension,
            Paramgen.Position AS [Position],
            pk.Stueck AS Qté,        
            COUNT(Paramgen.ArtikelID) * pk.Stueck AS [Nbr d'utilisations]
        FROM 
            dbo.P_Artikel AS Paramgen                
            LEFT JOIN dbo.A_Kopf AS Cde ON Cde.ID = Paramgen.ID_A_Kopf
            LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf

            LEFT JOIN dbo.P_Kaufm AS pk ON Cde.ID = pk.ID_A_Kopf AND Paramgen.Position = pk.Position 
        WHERE 
            cf.Feld3 BETWEEN '2024-12-01' AND '2024-12-31'
            AND Paramgen.ArtikelID = '6101'
        GROUP BY
            Cde.AuNummer,
            Paramgen.ArtikelID,
            Cde.AuAlpha,
            pk.Stueck,
            Paramgen.Position
    """
)
vn.train(
    question="Combien de châssis sont en préplanification ?", 
    sql="""
    SELECT 
        SUM(CAST(NM.Feld2 AS INT)) AS [Total Châssis en Préplanification]
    FROM 
        dbo.A_Kopf AS Cde
        INNER JOIN dbo.A_KopfFreie AS NM ON Cde.ID = NM.ID_A_Kopf
    WHERE 
        Cde.AufStatus = 'pré planif'
        AND CAST(NM.Feld2 AS INT) > 0
        AND Cde.AuAlpha NOT LIKE '%N%'
        AND Cde.AuAlpha NOT LIKE '%S%'
        AND Cde.AuAlpha NOT LIKE '%J%'
        AND Cde.AuAlpha NOT LIKE '%ECH%'
        AND Cde.AuAlpha NOT LIKE '%PFI%'
        AND Cde.AuAlpha NOT LIKE '%MKG%'
        AND Cde.AuAlpha NOT LIKE '%9%'
        AND Cde.AuAlpha NOT LIKE '%MUR%'
""")

vn.train(
    question="Quelle est la somme des chassis en pré-planif ?", 
    sql="""
    SELECT 
        SUM(TotalPreplanif) AS [Total de préplanif]
    FROM (
        SELECT
            COUNT(1) * NM.Feld2 AS TotalPreplanif
        FROM 
            dbo.A_Kopf AS Cde
            INNER JOIN dbo.A_KopfFreie AS NM ON Cde.ID = NM.ID_A_Kopf
        WHERE 
            Cde.AufStatus = 'pré planif'
            AND Cde.AuAlpha NOT LIKE '%N%'
            AND Cde.AuAlpha NOT LIKE '%S%'
            AND Cde.AuAlpha NOT LIKE '%J%'
            AND Cde.AuAlpha NOT LIKE '%ECH%'
            AND Cde.AuAlpha NOT LIKE '%PFI%'
            AND Cde.AuAlpha NOT LIKE '%MKG%'
            AND Cde.AuAlpha NOT LIKE '%9%'
            AND Cde.AuAlpha NOT LIKE '%MUR%'
            AND NM.Feld2 > 0
        GROUP BY NM.Feld2
    ) AS Subquery
    """
)
vn.train(
    question="Combien de chassis en pré-planif ?", 
    sql="""
    SELECT 
    SUM(CAST(NM.Feld2 AS INT)) AS [Total Châssis en Préplanif]
FROM 
    dbo.A_Kopf AS Cde
    INNER JOIN dbo.A_KopfFreie AS NM ON Cde.ID = NM.ID_A_Kopf
WHERE 
    Cde.AufStatus = 'pré planif'
    AND CAST(NM.Feld2 AS INT) > 0;
    """
)

vn.train(
    question="liste les commandes en préplanif", 
    sql="""
    WITH LatestOrders AS (
        SELECT
            CONVERT(VARCHAR, Cde.AuNummer) AS [N° de Cde],
            CONVERT(VARCHAR, Cde.AuAlpha) AS [Extension],
            CONVERT(INT, NM.Feld2) AS [Nbr Menuiserie],
            Cde.Kommission as [Affaire],
            ADR.Firma as [Client],
            Cde.Techniker as [Technicien],
            DATEPART(iso_week, DateSerie.Datum) AS [Semaine entrée cde],
            DATEPART(iso_week, NM.Feld5) AS [Semaine Livraison],
            Cde.AufStatus as [Status],
            DATEDIFF(DAY, DateSerie.Datum, GETDATE()) AS [Diff jours - Date entrée],
            DATEDIFF(DAY, NM.Feld5, GETDATE()) AS [Diff jours - Livraison],
            ROW_NUMBER() OVER (PARTITION BY Cde.AuNummer, Cde.AuAlpha ORDER BY DateSerie.Datum DESC) as RowNum
        FROM 
            dbo.A_Kopf AS Cde
            LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
            INNER JOIN dbo.A_Adresse AS ADR ON Cde.ID = ADR.ID_A_Kopf
          
        WHERE 
            Cde.AufStatus IN ('Pré planif')
            AND Cde.AuAlpha NOT LIKE '%N%'
            AND Cde.AuAlpha NOT LIKE '%S%'
            AND Cde.AuAlpha NOT LIKE '%J%'
            AND Cde.AuAlpha NOT LIKE '%ECH%'
            AND Cde.AuAlpha NOT LIKE '%PFI%'
            AND Cde.AuAlpha NOT LIKE '%MKG%'
            AND Cde.AuAlpha NOT LIKE '%9%'
            AND Cde.AuAlpha NOT LIKE '%MUR%'
            AND NM.Feld2 > 0
            AND DateSerie.Nummer LIKE '%entrée cde%'
            AND DateSerie.Nummer NOT LIKE '%_CdeModifiée%'
            AND DateSerie.Nummer NOT LIKE '%_Mess. Client%'
            AND ADR.Firma NOT LIKE ''
    )
    SELECT 
        [N° de Cde],
        [Extension],
        [Nbr Menuiserie],
        [Affaire],
        [Client],
        [Technicien],
        [Semaine entrée cde],
        [Semaine Livraison],
        [Status],
        [Diff jours - Date entrée],
        [Diff jours - Livraison]
    FROM LatestOrders
    WHERE RowNum = 1
    """
)

vn.train(
    question="Combien de chassis sont entrés aujourd'hui ?", 
    sql="""
    SELECT 
        SUM([Nbr de chassis entrés aujourd'hui]) AS [Nbr de chassis entrés aujourd'hui]
    FROM (
        SELECT
            COUNT(1) * cf.Feld2 AS [Nbr de chassis entrés aujourd'hui]
        FROM
            dbo.A_Kopf AS Cde
            LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
        WHERE
            CONVERT(DATE, cf.Feld3) = CONVERT(DATE, GETDATE())
            AND Cde.AuAlpha NOT LIKE '%N%'
            AND Cde.AuAlpha NOT LIKE '%S%'
            AND Cde.AuAlpha NOT LIKE '%J%'
            AND Cde.AuAlpha NOT LIKE '%ECH%'
            AND Cde.AuAlpha NOT LIKE '%PFI%'
            AND Cde.AuAlpha NOT LIKE '%MKG%'
            AND Cde.AuAlpha NOT LIKE '%9%'
            AND Cde.AuAlpha NOT LIKE '%MUR%'
        GROUP BY cf.Feld2
    ) AS Subquery
"""
)
vn.train(
    question="Combien de chassis ont été saisies aujourd'hui ?", 
    sql="""
    SELECT 
    SUM(CAST(NM.Feld2 AS INT)) AS [Total Châssis Saisis Aujourd'hui]
FROM 
    dbo.A_Kopf AS Cde
    INNER JOIN dbo.A_Vorgang AS DateSerie ON DateSerie.ID_A_Kopf = Cde.ID
    INNER JOIN dbo.A_KopfFreie AS NM ON Cde.ID = NM.ID_A_Kopf
WHERE 
    CONVERT(DATE, DateSerie.Datum) = CONVERT(DATE, GETDATE())
    AND DateSerie.Nummer LIKE '%entrée cde%'
    AND Cde.AuAlpha NOT LIKE '%N%'
    AND Cde.AuAlpha NOT LIKE '%S%'
    AND Cde.AuAlpha NOT LIKE '%J%'
    AND Cde.AuAlpha NOT LIKE '%ECH%'
    AND Cde.AuAlpha NOT LIKE '%PFI%'
    AND Cde.AuAlpha NOT LIKE '%MKG%'
    AND Cde.AuAlpha NOT LIKE '%9%'
    AND Cde.AuAlpha NOT LIKE '%MUR%'
    """
)
vn.train(
    question="Combien de chassis ont été saisies aujourd'hui par technicien ?", 
    sql="""
    SELECT
        Cde.Techniker AS [Technicien],
        SUM(CASE 
            WHEN Cde.AufStatus = 'BLOQ CC' AND DateSerie.Nummer LIKE '%q CC%' THEN cf.Feld2 
            ELSE 0 
        END) AS [total de BLOQ CC],
        SUM(CASE 
            WHEN Cde.AufStatus = 'BLOQ saisie' AND DateSerie.Nummer LIKE '%Impr%' THEN cf.Feld2 
            ELSE 0 
        END) AS [total de BLOQ saisie],
        SUM(CASE 
            WHEN Cde.AufStatus = 'BLOQ CC' AND DateSerie.Nummer LIKE '%q CC%' THEN Cde.A_VorMwSt 
            WHEN Cde.AufStatus = 'BLOQ saisie' AND DateSerie.Nummer LIKE '%Impr%' THEN Cde.A_VorMwSt 
            ELSE 0 
        END) AS [Prix HT Total]
    FROM 
        dbo.A_Kopf AS Cde
        INNER JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
        INNER JOIN dbo.A_Vorgang AS DateSerie ON DateSerie.ID_A_Kopf = Cde.ID
    WHERE 
        Cde.Techniker IS NOT NULL
        AND Cde.Techniker NOT LIKE '%cindy%'
        AND Cde.Techniker NOT LIKE '%morgan%'
        AND Cde.Techniker NOT LIKE '%AURELIE MASSET%'
        AND Cde.Techniker NOT LIKE '%MANUELDAEVIDOZO%'
        AND Cde.Techniker NOT LIKE '%MELANIE SANDRE%'
        AND Cde.Techniker NOT LIKE '%JEROME%'
        AND Cde.Techniker NOT LIKE '%Antoine%'
        AND Cde.Techniker NOT LIKE '%GEORGE HENRI%'
        AND Cde.AufStatus IN ('BLOQ CC', 'BLOQ saisie')
        AND CONVERT(DATE, DateSerie.Datum) = CONVERT(DATE, GETDATE())
    GROUP BY Cde.Techniker
    """
)
vn.train(
    question="Liste moi les commandes bloquées aujourd'hui", 
    sql="""
    SELECT
        CONVERT(VARCHAR, Cde.AuNummer) AS [N° de Cde],
        CONVERT(VARCHAR, Cde.AuAlpha) AS [Extension],
        CONVERT(INT, cf.Feld2) AS [Nbr Menuiserie],
        Cde.AufStatus as [Status],
        Cde.Techniker AS [Technicien]
    FROM 
        dbo.A_Kopf AS Cde
        INNER JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
        INNER JOIN dbo.A_Vorgang AS DateSerie ON DateSerie.ID_A_Kopf = Cde.ID
    WHERE 
        Cde.Techniker IS NOT NULL
        AND Cde.AufStatus IN ('BLOQ CC', 'BLOQ saisie')
        AND CONVERT(DATE, DateSerie.Datum) = CONVERT(DATE, GETDATE())
    """
)
vn.train(
    question="Liste moi toutes les commandes bloquées", 
    sql="""
        SELECT
            CONVERT(VARCHAR, Cde.AuNummer) AS [N° de Cde],
            CONVERT(VARCHAR, Cde.AuAlpha) AS [Extension],
            CONVERT(INT, NM.Feld2) AS [Nbr Menuiserie],
            ADR.Firma as [Client],
            Cde.AufStatus as [Status]
        FROM 
            dbo.A_Kopf AS Cde
            INNER JOIN dbo.A_KopfFreie AS NM ON Cde.ID = NM.ID_A_Kopf
            INNER JOIN dbo.A_Adresse AS ADR ON Cde.ID = ADR.ID_A_Kopf
        WHERE 
            Cde.AufStatus LIKE '%bloq%'
            AND ADR.Firma IS NOT NULL
            AND ADR.Firma NOT LIKE ''

        GROUP BY
            Cde.AuNummer,
            Cde.AuAlpha,
            Cde.AufStatus,
            NM.Feld2,
            ADR.Firma,
            Cde.Techniker,
            NM.Feld5
        ORDER BY 
            Cde.AufStatus ASC
        """
)
vn.train(
    question="liste moi les commandes de février 2025 avec un montant ht supérieur à 2000 €", 
    sql="""SELECT 
        Cde.AuNummer AS [N° de Cde],
        Cde.AuAlpha AS [Extension],
        SUM(Cde.A_VorMwSt) AS [Montant HT],
        CONVERT(DATE, cf.Feld3) AS [Date de commande]
    FROM 
        dbo.A_Kopf AS Cde
        LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
    WHERE 
        CONVERT(DATE, cf.Feld3) BETWEEN '2025-02-01' AND '2025-03-01'
        AND Cde.A_VorMwSt > 2000
    GROUP BY 
        Cde.AuNummer, Cde.AuAlpha, cf.Feld3"""
)
vn.train(
    question="liste moi les commandes de février 2025 avec un montant ht supérieur à 1000 €", 
    sql="""SELECT 
        Cde.AuNummer AS [N° de Cde],
        Cde.AuAlpha AS [Extension],
        SUM(Prix.VkNRabMalStk) AS [Montant HT],
        CONVERT(DATE, cf.Feld3) AS [Date entrée de commande]
        FROM 
                dbo.A_Kopf AS Cde
                LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
                INNER JOIN dbo.P_Kaufm AS Prix ON Cde.ID = Prix.ID_A_Kopf
        WHERE 
                CONVERT(DATE, cf.Feld3) >= '2025-02-01' 
                AND CONVERT(DATE, cf.Feld3) < '2025-03-01'
        GROUP BY 
                Cde.AuNummer, Cde.AuAlpha, cf.Feld3
        HAVING 
                SUM(Prix.VkNRabMalStk) > 1000"""
)
vn.train(
    question="Donne le nombre d'utilisation et le montant HT de la variante 224 au premier trimestre 2025", 
    sql="""
    SELECT
        Variante.Variante AS [Variante],
        SUM(Prix.Stueck) AS [Nbr d'utilisations],
        SUM(Prix.VkNRabMalStk) AS [CA HT position],
        CONVERT(DATE, cf.Feld3) AS [Date de commande]
    FROM 
        dbo.P_Teil AS Variante
        INNER JOIN dbo.A_Kopf AS Cde ON Cde.ID = Variante.ID_A_Kopf
        INNER JOIN dbo.P_Kaufm AS Prix ON Cde.ID = Prix.ID_A_Kopf AND Variante.Position = Prix.Position
        LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
    WHERE 
        Variante.Variante = '224'
        AND Prix.Position > 0
        AND cf.Feld3 BETWEEN '2025-01-01' AND '2025-03-31'
    GROUP BY
        Variante.Variante, cf.Feld3
    ORDER BY
        [Date de commande]"""
)
vn.train(
    question="Liste moi les commandes des 30 derniers jours contenant l'article 224 avec le status facturée", 
    sql="""
    SELECT
        CONVERT(VARCHAR, Cde.AuNummer) AS [N° de Cde],
        CONVERT(VARCHAR, Cde.AuAlpha) AS [Extension],
        Variante.Variante AS [Variante],
        CONVERT(DATE, cf.Feld3) AS [Date entrée cde],
        Cde.AufStatus as [Status]
    FROM 
        dbo.P_Teil AS Variante
        INNER JOIN dbo.A_Kopf AS Cde ON Cde.ID = Variante.ID_A_Kopf
        INNER JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf
    WHERE 
        CONVERT(DATE, cf.Feld3) BETWEEN DATEADD(DAY, -30, GETDATE()) AND GETDATE()
        AND Cde.AufStatus IN ('facturée')
        AND Variante.Variante = '224'
    GROUP BY
        CONVERT(VARCHAR, Cde.AuNummer),
        CONVERT(VARCHAR, Cde.AuAlpha),
        Variante.Variante,
        CONVERT(DATE, cf.Feld3),
        CAST(YEAR(cf.Feld3) AS INT),
        CAST(MONTH(cf.Feld3) AS INT),
        cf.Feld3,
        Cde.AufStatus
    ORDER BY
        [Date entrée cde] DESC
    """
)
vn.train(
    question="trouve moi les numero de commande et extension qui contiennent l'article SBST M AUWS 28 qui n'ont pas le status facturée", 
    sql=""" 
        SELECT DISTINCT 
            Cde.AuNummer AS [N° de Cde],
            Cde.AuAlpha AS [Extension]
        FROM 
            dbo.A_Kopf AS Cde
            INNER JOIN dbo.P_Artikel AS Paramgen ON Cde.ID = Paramgen.ID_A_Kopf
        WHERE 
            Paramgen.ArtikelID = 'SBST M AUWS 28'
            AND Cde.AufStatus <> 'facturée'
    """
)
vn.train(
    question="trouve moi les numero de commande et extension avec la date de commande soubassement qui contiennent le soubassement code article SBST M AUWS 28 qui n'ont pas le status facturée", 
    sql=""" 
        SELECT DISTINCT 
            Cde.AuNummer AS [N° de Cde],
            Cde.AuAlpha AS [Extension],
            cf.Feld1 AS [Date de commande soubassement]
        FROM 
            dbo.A_Kopf AS Cde
            INNER JOIN dbo.P_Artikel AS Paramgen ON Cde.ID = Paramgen.ID_A_Kopf
            LEFT JOIN dbo.A_KopfFreie AS cf ON Cde.ID = cf.ID_A_Kopf

        WHERE 
            Paramgen.ArtikelID = 'SBST M AUWS 28'
            AND Cde.AufStatus <> 'facturée'
    """
)
# Out:
# '9f941d60-f376-5e83-9556-ee6ede3b6f3b-sql'

# %%
training_data = vn.get_training_data()
training_data
# Out:
#                                           id  \
# 0   c4ca5b38-b8b5-5ada-a001-6555c30dab61-sql
# 1   3daae30c-356d-5dd8-b149-6349c8717b57-sql
# 2   470127fb-8b7d-56e0-9a5b-40d7de2b4022-sql
# 3   6f4fa07a-f1a6-5e9c-a95b-05fe536ef47f-sql
# 4   2920edb9-0dc8-59b5-8b00-442c243758c3-sql
# 5   c1857709-7e17-5c14-93be-91fc15a86801-sql
# 6   8cf5f60d-4578-5057-b81f-48e6fc7c95d1-sql
# 7   5662d916-ed24-585f-b7cd-3bff5456cefc-sql
# 8   99c5b292-e06a-5b03-9f6e-3e9bda4a8bcd-sql
# 9   3f91f181-b92b-5eb8-a5a0-203069648dd4-sql
# 10  55477874-92d6-5cc9-9e2d-2fb9caf09c97-sql
# 11  7f76db87-5c88-5cdc-bffa-e411e6bc5533-sql
# 12  ba65687f-0e4e-597c-bb58-d0e49e43cb4b-sql
# 13  721b94f3-5ace-567e-8e10-23536959458b-sql
# 14  d50889b0-d677-5bbc-8d48-71bdb446177d-sql
# 15  64b8e840-42af-54d0-88eb-25e0922b21c3-sql
# 16  707a1ed3-ceb6-5646-b6d2-167db3f8c953-sql
# 17  9f941d60-f376-5e83-9556-ee6ede3b6f3b-sql
# 0   8f932125-c326-5c80-9d3f-bd37c029ed6d-doc
# 1   80810e70-695c-54d4-a33b-d7105ef7c669-doc
# 2   c91d4058-1d01-576d-b1e3-362db84e22e7-doc
# 3   cddd5f0a-593c-58a8-b09e-2804c2da9a2b-doc
# 4   d2227ee3-f380-50d7-845c-9f155a60a287-doc
# 5   66e367d6-0195-5b5b-8dfa-72bbe65f10c5-doc
# 6   587d8caf-bfdf-5ef0-814f-d0d4c9c6ed18-doc
# 7   3677625d-16e7-5a4b-98cc-cd6f6592f766-doc
# 8   9a98b395-fa89-50b9-a77f-fdee88b3412f-doc
#
#                                              question  \
# 0   Combien de fois un article a-t-il été utilisé,...
# 1   liste moi les 10 dernieres commandes avec leur...
# 2   Liste des commandes où l'article 6101 est prés...
# 3       Combien de châssis sont en préplanification ?
# 4     Quelle est la somme des chassis en pré-planif ?
# 5                  Combien de chassis en pré-planif ?
# 6                    liste les commandes en préplanif
# 7        Combien de chassis sont entrés aujourd'hui ?
# 8    Combien de chassis ont été saisies aujourd'hui ?
# 9   Combien de chassis ont été saisies aujourd'hui...
# 10       Liste moi les commandes bloquées aujourd'hui
# 11            Liste moi toutes les commandes bloquées
# 12  liste moi les commandes de février 2025 avec u...
# 13  liste moi les commandes de février 2025 avec u...
# 14  Donne le nombre d'utilisation et le montant HT...
# 15  Liste moi les commandes des 30 derniers jours ...
# 16  trouve moi les numero de commande et extension...
# 17  trouve moi les numero de commande et extension...
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
#
#                                               content training_data_type
# 0   \n    SELECT \n        Paramgen.ArtikelID AS [...                sql
# 1   SELECT TOP 10 \n            Cde.AuNummer as [N...                sql
# 2   \n        SELECT\n            Paramgen.Artikel...                sql
# 3   \n    SELECT \n        SUM(CAST(NM.Feld2 AS IN...                sql
# 4   \n    SELECT \n        SUM(TotalPreplanif) AS ...                sql
# 5   \n    SELECT \n    SUM(CAST(NM.Feld2 AS INT)) ...                sql
# 6   \n    WITH LatestOrders AS (\n        SELECT\n...                sql
# 7   \n    SELECT \n        SUM([Nbr de chassis ent...                sql
# 8   \n    SELECT \n    SUM(CAST(NM.Feld2 AS INT)) ...                sql
# 9   \n    SELECT\n        Cde.Techniker AS [Techni...                sql
# 10  \n    SELECT\n        CONVERT(VARCHAR, Cde.AuN...                sql
# 11  \n        SELECT\n            CONVERT(VARCHAR,...                sql
# 12  SELECT \n        Cde.AuNummer AS [N° de Cde],\...                sql
# 13  SELECT \n        Cde.AuNummer AS [N° de Cde],\...                sql
# 14  \n    SELECT\n        Variante.Variante AS [Va...                sql
# 15  \n    SELECT\n        CONVERT(VARCHAR, Cde.AuN...                sql
# 16   \n        SELECT DISTINCT \n            Cde.A...                sql
# 17   \n        SELECT DISTINCT \n            Cde.A...                sql
# 0   The following columns are in the A_Adresse tab...      documentation
# 1   The following columns are in the A_Kopf table ...      documentation
# 2   The following columns are in the A_KopfFreie t...      documentation
# 3   The following columns are in the A_Vorgang tab...      documentation
# 4   The following columns are in the P_Artikel tab...      documentation
# 5   The following columns are in the P_Kaufm table...      documentation
# 6   The following columns are in the P_Teil table ...      documentation
# 7   The following columns are in the P_Werkstoffe ...      documentation
# 8   The following columns are in the P_Zubeh table...      documentation

# %%
# reponse = vn.ask("liste moi les 10 dernieres commandes ?")
# print(reponse)

# %%
from vanna.flask import VannaFlaskApp
VannaFlaskApp(vn, allow_llm_to_see_data=True).run()
# Out:
# Your app is running at:
# http://localhost:8084
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: on
# Traceback (most recent call last):
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\vanna\flask\__init__.py", line 138, in decorated
#     return f(*args, user=user, **kwargs)
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\vanna\flask\__init__.py", line 335, in generate_sql
#     sql = vn.generate_sql(question=question, allow_llm_to_see_data=self.allow_llm_to_see_data)
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\vanna\base\base.py", line 136, in generate_sql
#     llm_response = self.submit_prompt(prompt, **kwargs)
#   File "c:\Users\elie.lecas\Documents\Code\vanna_ai\.venv\Lib\site-packages\vanna\ollama\ollama.py", line 91, in submit_prompt
#     f"model={self.model},\n"
#              ^^^^^^^^^^
# AttributeError: 'MyVanna' object has no attribute 'model'

# %%
# Out:
# Requirement already satisfied: vanna[chromadb,ollama] in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (0.7.6)
# Requirement already satisfied: requests in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (2.32.3)
# Requirement already satisfied: tabulate in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (6.0.1)
# Requirement already satisfied: pandas in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (2.2.3)
# Requirement already satisfied: sqlparse in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.2.1)
# Requirement already satisfied: flask in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (3.1.0)
# Requirement already satisfied: flask-sock in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (2.0.40)
# Requirement already satisfied: chromadb in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (1.0.15)
# Requirement already satisfied: ollama in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.5.1)
# Requirement already satisfied: httpx in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from vanna[chromadb,ollama]) (0.28.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (2.11.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (2.2.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.13.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (3.11.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from chromadb->vanna[chromadb,ollama]) (4.23.0)
# Requirement already satisfied: anyio in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (4.9.0)
# Requirement already satisfied: certifi in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (1.0.7)
# Requirement already satisfied: idna in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpx->vanna[chromadb,ollama]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from httpcore==1.*->httpx->vanna[chromadb,ollama]) (0.14.0)
# Requirement already satisfied: mistune in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,ollama]) (3.1.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,ollama]) (1.17.0)
# Requirement already satisfied: packaging in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flasgger->vanna[chromadb,ollama]) (24.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask->vanna[chromadb,ollama]) (1.9.0)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from flask-sock->vanna[chromadb,ollama]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,ollama]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,ollama]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pandas->vanna[chromadb,ollama]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from plotly->vanna[chromadb,ollama]) (1.33.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,ollama]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from requests->vanna[chromadb,ollama]) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from sqlalchemy->vanna[chromadb,ollama]) (3.1.1)
# Requirement already satisfied: pyproject_hooks in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from build>=1.0.3->chromadb->vanna[chromadb,ollama]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from build>=1.0.3->chromadb->vanna[chromadb,ollama]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from Jinja2>=3.1.2->flask->vanna[chromadb,ollama]) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->vanna[chromadb,ollama]) (0.24.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (6.31.1)
# Requirement already satisfied: sympy in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,ollama]) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,ollama]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,ollama]) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->vanna[chromadb,ollama]) (0.56b0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->vanna[chromadb,ollama]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->vanna[chromadb,ollama]) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,ollama]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,ollama]) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,ollama]) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,ollama]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,ollama]) (2.19.1)
# Requirement already satisfied: wsproto in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,ollama]) (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb->vanna[chromadb,ollama]) (0.33.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from typer>=0.9.0->chromadb->vanna[chromadb,ollama]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,ollama]) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from anyio->httpx->vanna[chromadb,ollama]) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (4.9.1)
# Requirement already satisfied: filelock in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,ollama]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,ollama]) (2025.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,ollama]) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->vanna[chromadb,ollama]) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,ollama]) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\elie.lecas\documents\code\vanna_ai\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,ollama]) (0.6.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
